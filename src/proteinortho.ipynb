# %% [markdown]
# # Командная часть

# %%
! wget -O com_protein.grayi.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/691/245/GCA_000691245.1_Tgr_V1/GCA_000691245.1_Tgr_V1_protein.faa.gz'
! wget -O com_protein.martiniquensis.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/017/916/325/GCA_017916325.1_LU_Lmar_1.0/GCA_017916325.1_LU_Lmar_1.0_protein.faa.gz'
! wget -O com_protein.braziliensis.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/002/845/GCF_000002845.2_ASM284v2/GCF_000002845.2_ASM284v2_protein.faa.gz'
! wget -O com_protein.hertigi.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/017/918/235/GCA_017918235.1_LU_Pher_1.0/GCA_017918235.1_LU_Pher_1.0_protein.faa.gz'
! wget -O com_protein.orientalis.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/017/916/335/GCA_017916335.1_LU_Lori_1.0/GCA_017916335.1_LU_Lori_1.0_protein.faa.gz'
! wget -O com_protein.pyrrhocoris.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001/293/395/GCA_001293395.1_ASM129339v1/GCA_001293395.1_ASM129339v1_protein.faa.gz'
! wget -O com_protein.CCAP.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001/235/845/GCA_001235845.1_ASM123584v1/GCA_001235845.1_ASM123584v1_protein.faa.gz'
! wget -O com_protein.Hart1.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/982/615/GCA_000982615.1_AKI_PRJEB1539_v1/GCA_000982615.1_AKI_PRJEB1539_v1_protein.faa.gz'
! wget -O com_protein.theileri.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002/087/225/GCA_002087225.1_Tth_v3/GCA_002087225.1_Tth_v3_protein.faa.gz'
! wget -O com_protein.donovani.faa.gz 'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/227/135/GCA_000227135.2_ASM22713v2/GCA_000227135.2_ASM22713v2_protein.faa.gz'
# Out:
# --2022-06-15 12:57:01--  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000/691/245/GCA_000691245.1_Tgr_V1/GCA_000691245.1_Tgr_V1_protein.faa.gz
# Распознаётся ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)… 130.14.250.10, 130.14.250.12, 2607:f220:41f:250::228, ...
# Подключение к ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.10|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 200 OK
# Длина: 2934145 (2,8M) [application/x-gzip]
# Сохранение в: «com_protein.grayi.faa.gz»
#
# com_protein.grayi.f 100%[===================>]   2,80M  2,06MB/s    за 1,4s
#
# 2022-06-15 12:57:03 (2,06 MB/s) - «com_protein.grayi.faa.gz» сохранён [2934145/2934145]
#
# --2022-06-15 12:57:03--  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/017/916/325/GCA_017916325.1_LU_Lmar_1.0/GCA_017916325.1_LU_Lmar_1.0_protein.faa.gz
# Распознаётся ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)… 130.14.250.12, 130.14.250.10, 2607:f220:41f:250::228, ...
# ...

# %%
# !gzip -d com*.faa.gz

# %%
files  = ! find . -maxdepth 1 -type f

# %%
import numpy as np

# %%
files = ! ls -d ./com_*
files
# Out:
# ['./com_protein.CCAP.faa',
#  './com_protein.Hart1.faa',
#  './com_protein.braziliensis.faa',
#  './com_protein.donovani.faa',
#  './com_protein.grayi.faa',
#  './com_protein.hertigi.faa',
#  './com_protein.martiniquensis.faa',
#  './com_protein.orientalis.faa',
#  './com_protein.pyrrhocoris.faa',
#  './com_protein.theileri.faa']

# %%
for i in range(0, len(files)):
    files[i] = files[i][2:]
files
# Out:
# ['com_protein.CCAP.faa',
#  'com_protein.Hart1.faa',
#  'com_protein.braziliensis.faa',
#  'com_protein.donovani.faa',
#  'com_protein.grayi.faa',
#  'com_protein.hertigi.faa',
#  'com_protein.martiniquensis.faa',
#  'com_protein.orientalis.faa',
#  'com_protein.pyrrhocoris.faa',
#  'com_protein.theileri.faa']

# %%
# !proteinortho  -cpus=8 com_protein.CCAP.faa com_protein.Hart1.faa com_protein.braziliensis.faa com_protein.donovani.faa com_protein.grayi.faa com_protein.hertigi.faa com_protein.martiniquensis.faa com_protein.orientalis.faa com_protein.pyrrhocoris.faa com_protein.theileri.faa
# Out:
# *****************************************************************
# Proteinortho with PoFF version 6.0.35 - An orthology detection tool
# *****************************************************************
# Using 8 CPU threads, Detected 'diamond' version 2.0.15
# Checking input files.
# Checking com_protein.CCAP.faa... ok
# Checking com_protein.Hart1.faa... ok
# Checking com_protein.braziliensis.faa... ok
# Checking com_protein.donovani.faa... ok
# Checking com_protein.grayi.faa... ok
# Checking com_protein.hertigi.faa... ok
# Checking com_protein.martiniquensis.faa... ok
# Checking com_protein.orientalis.faa... ok
# Checking com_protein.pyrrhocoris.faa... ok
# Checking com_protein.theileri.faa... ok
#
# **Step 1**
# Generating indices.
# Building database for 'com_protein.pyrrhocoris.faa'	(13893 sequences)
# Building database for 'com_protein.theileri.faa'	(11312 sequences)
# Building database for 'com_protein.grayi.faa'	(10583 sequences)
# ...

# %%
! ls -d ./my*
# Out:
# ./my_res                               ./myproject.proteinortho-graph
# ./myproject.blast-graph                ./myproject.proteinortho-graph.summary
# ./myproject.info                       ./myproject.proteinortho.tsv

# %%
import pandas as pd

# %%
clust = pd.read_csv('myproject.proteinortho.tsv', sep='\t')
clust
# Out:
#        # Species  Genes  Alg.-Conn.   com_protein.CCAP.faa  \
# 0             10     37       0.326  KNH08328.1,KNH09706.1
# 1             10     31       0.272             KNH06083.1
# 2             10     30       0.253             KNH04116.1
# 3             10     27       0.327             KNH07933.1
# 4             10     25       0.589  KNH05062.1,KNH06686.1
# ...          ...    ...         ...                    ...
# 10327          2      2       1.000             KNH09163.1
# 10328          2      2       1.000             KNH09239.1
# 10329          2      2       1.000             KNH09262.1
# 10330          2      2       1.000             KNH09293.1
# 10331          2      2       1.000             KNH09714.1
#
#       com_protein.Hart1.faa  \
# 0                CCW66145.1
# 1                CCW69317.1
# 2                CCW68146.1
# 3                CCW70184.1
# 4                CCW70890.1
# ...                     ...
# 10327                     *
# ...
